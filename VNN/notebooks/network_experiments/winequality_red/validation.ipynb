# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 10]

import os
import sys
import inspect
module_path = os.path.abspath(os.path.join('../../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from dataset.dataset import get_test_datasets, get_validation_datasets, get_dataset_shapes
from experiment.model import get_scalar_model, get_vector_model
from experiment.learning import validate_model, validate_model_multiple, test_model, test_model_multiple

# %%
train_dataset, test_dataset = get_test_datasets('winequality_red', random_seed=200, feature_range=(0,1))
datasets_generator_fun = lambda: get_validation_datasets('winequality_red', random_seed=200, feature_range=(0,1))
dataset_shapes = get_dataset_shapes('winequality_red')

dataset_shapes
# Out:
# ([11], [1])

# %% [markdown]
# # Scalar network without hidden layers

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 211.42516 sec
# Last measures: [0.07154897600412369, 0.13277091272175312, 0.13274896182119847, 0.01796411257237196, 0.07822924274951219]

# %% [markdown]
# # Scalar network with one hidden layer

# %% [markdown]
# ### S(2)

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[2], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 248.63755 sec
# Last measures: [0.20099877398461102, 0.24649136736989022, 0.132629506662488, 0.18882812857627868, 0.1334608606994152]

# %% [markdown]
# ### S(5)

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[5], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 249.02048 sec
# Last measures: [0.01782040949910879, 0.07314573414623737, 0.3076862931251526, 0.192901829816401, 0.24739223793148996]

# %% [markdown]
# ### S(15)

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[15], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 250.28682 sec
# Last measures: [0.07799077983945608, 0.07694576717913151, 0.19864688143134118, 0.1343686817213893, 0.191125176474452]

# %% [markdown]
# ### S(30)

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[30], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 247.53531 sec
# Last measures: [0.13334702812135218, 0.18601689748466016, 0.07121801041066647, 0.19391807224601507, 0.017544405162334444]

# %% [markdown]
# # Scalar network with three hidden layers

# %% [markdown]
# ### S(2,2,2)

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[2,2,2], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 324.05692 sec
# Last measures: [0.2559282500296831, 0.25237510055303575, 0.255930395424366, 0.08398668318986893, 0.19459580071270466]

# %% [markdown]
# ### S(10,7,5)

# %%
model_fun = lambda: get_scalar_model(dataset_shapes, hidden_layer_units=[10,7,5], activation='relu', output_activation=None, \
    kernel_initializer='random_normal', bias_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 322.88242 sec
# Last measures: [0.07327528279274702, 0.19379765242338182, 0.18799150325357913, 0.1938331039622426, 0.1911907520145178]

# %% [markdown]
# # Vector network with one hidden layer (c=1), unique weights

# %% [markdown]
# ### V1(2):U(2)

# %%
model_fun = lambda: get_vector_model(dataset_shapes, fractal_depth=1, hidden_layer_units=(2,), inner_hidden_layer_units=(2,), \
    activation='relu', output_activation=None, \
    weight_type="unique", weight_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 337.37183 sec
# Last measures: [0.1930458053946495, 0.19438385255634785, 0.24991736598312855, 0.18881952241063119, 0.18969083540141582]

# %% [markdown]
# ### V1(5):U(2)

# %%
model_fun = lambda: get_vector_model(dataset_shapes, fractal_depth=1, hidden_layer_units=(5,), inner_hidden_layer_units=(2,), \
    activation='relu', output_activation=None, \
    weight_type="unique", weight_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 336.38881 sec
# Last measures: [0.18794709555804728, 0.07997380383312702, 0.08127768225967884, 0.1878946103155613, 0.13429774343967438]

# %% [markdown]
# # Vector network with one hidden layer (c=1), shared weights

# %% [markdown]
# ### V1(2):S(2)

# %%
model_fun = lambda: get_vector_model(dataset_shapes, fractal_depth=1, hidden_layer_units=(2,), inner_hidden_layer_units=(2,), \
    activation='relu', output_activation=None, \
    weight_type="shared", weight_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 377.43547 sec
# Last measures: [0.3076862931251526, 0.2482295498251915, 0.08161933459341526, 0.1345153834670782, 0.02367730960249901]

# %% [markdown]
# ### V1(5):S(2)

# %%
model_fun = lambda: get_vector_model(dataset_shapes, fractal_depth=1, hidden_layer_units=(5,), inner_hidden_layer_units=(2,), \
    activation='relu', output_activation=None, \
    weight_type="shared", weight_initializer='random_normal', \
    optimizer=keras.optimizers.RMSprop(), loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.MeanSquaredError()])

validate_model_multiple(model_fun, datasets_generator_fun, epochs=100, num_tries=5, \
    loss_name="mean_squared_error", measure_name="val_mean_squared_error")
# Out:
# Average elapsed k-fold validation time: 353.82268 sec
# Last measures: [0.19208037853240967, 0.13354360703378915, 0.1336521739140153, 0.3076862931251526, 0.1312048092484474]
