# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 10]

import os
import sys
import inspect
module_path = os.path.abspath(os.path.join('../../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from dataset.dataset import get_test_datasets, get_validation_datasets, get_dataset_shapes
from experiment.model import get_scalar_conv_model2, get_vector_conv_model2, get_le_net_5, get_le_net_5_without_fully_connected, get_le_net_5_fractal1, get_le_net_5_fractal2, get_le_net_5_fractal3, get_le_net_5_fractal4, get_le_net_5_fractal5, get_le_net_5_fractal6
from experiment.learning import validate_model, validate_model_multiple, test_model, test_model_multiple

# %%
train_dataset, test_dataset = get_test_datasets('mnist', random_seed=200, feature_range=(0,1))
datasets_generator_fun = lambda: get_validation_datasets('mnist', random_seed=200, feature_range=(0,1))
dataset_shapes = get_dataset_shapes('mnist')

dataset_shapes
# Out:
# ([28, 28, 1], [10])

# %% [markdown]
# ### LeNet-5

# %%
model = get_le_net_5(dataset_shapes)

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 321.26342 sec
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 28, 28, 6)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 10, 10, 16)        2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5(dataset_shapes)

test_model(model, train_dataset, test_dataset, epochs=100, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 645.57501 sec
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 6)         156
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 28, 28, 6)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 10, 10, 16)        2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_without_fully_connected(dataset_shapes)

test_model(model, train_dataset, test_dataset, epochs=100, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 646.34566 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# re_lu (ReLU)                 (None, 28, 28, 6)         0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal1(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=100, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 3754.26580 sec
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_2 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_2 (VConvFract (None, 4, 14, 14, 6)      64
# _________________________________________________________________
# v_output_conv_2 (VOutputConv (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal1(dataset_shapes, False)

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 1778.23638 sec
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_1 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 4, 14, 14, 6)      384
# _________________________________________________________________
# v_output_conv_1 (VOutputConv (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal2(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 3178.26869 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# re_lu (ReLU)                 (None, 28, 28, 6)         0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# v_input_conv (VInputConv)    (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal2(dataset_shapes, False)

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 3254.40088 sec
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 28, 28, 6)         0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# v_input_conv_1 (VInputConv)  (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal3(dataset_shapes, False)

test_model(model, train_dataset, test_dataset, epochs=10, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 351.42482 sec
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_1 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 4, 14, 14, 6)      384
# _________________________________________________________________
# v_output_conv_1 (VOutputConv (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1, 1, 10)          11770
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal3(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=10, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 351.52939 sec
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_2 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_2 (VConvFract (None, 4, 14, 14, 6)      64
# _________________________________________________________________
# v_output_conv_2 (VOutputConv (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 10)          11770
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal4(dataset_shapes, False)

test_model(model, train_dataset, test_dataset, epochs=10, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 118.62827 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv (VInputConv)    (None, 26, 28, 28, 1)     26
# _________________________________________________________________
# v_conv_fractal (VConvFractal (None, 4, 14, 14, 1)      64
# _________________________________________________________________
# v_output_conv (VOutputConv)  (None, 14, 14, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 10, 10, 16)        416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal4(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=10, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 117.58418 sec
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_1 (VInputConv)  (None, 26, 28, 28, 1)     26
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 4, 14, 14, 1)      64
# _________________________________________________________________
# v_output_conv_1 (VOutputConv (None, 14, 14, 1)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        416
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, False)

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 4666.05578 sec
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_2 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_4 (VConvFract (None, 4, 14, 14, 6)      384
# _________________________________________________________________
# v_conv_4 (VConv)             (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_5 (VConvFract (None, 4, 5, 5, 16)       5024
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 4639.56521 sec
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_3 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_6 (VConvFract (None, 4, 14, 14, 6)      64
# _________________________________________________________________
# v_conv_6 (VConv)             (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_7 (VConvFract (None, 4, 5, 5, 16)       314
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(1,))

test_model(model, train_dataset, test_dataset, epochs=10, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 375.02058 sec
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_8 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_7 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_14 (VConvFrac (None, 4, 14, 14, 6)      34
# _________________________________________________________________
# v_conv_14 (VConv)            (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_15 (VConvFrac (None, 4, 5, 5, 16)       159
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(1,), activation='tanh')

test_model(model, train_dataset, test_dataset, epochs=10, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 375.29172 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv (VInputConv)    (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal (VConvFractal (None, 4, 14, 14, 6)      34
# _________________________________________________________________
# v_conv (VConv)               (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 4, 5, 5, 16)       159
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(2,), activation='tanh')

test_model(model, train_dataset, test_dataset, epochs=50, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 4692.75892 sec
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_1 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_2 (VConvFract (None, 4, 14, 14, 6)      64
# _________________________________________________________________
# v_conv_2 (VConv)             (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_3 (VConvFract (None, 4, 5, 5, 16)       314
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(2,), activation='tanh', optimizer=keras.optimizers.Adam())

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 469.75140 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv (VInputConv)    (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal (VConvFractal (None, 4, 14, 14, 6)      64
# _________________________________________________________________
# v_conv (VConv)               (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 4, 5, 5, 16)       314
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(2,), activation='tanh', optimizer=keras.optimizers.Adam())

test_input = tf.random.uniform(
    (1, 28, 28, 1), minval=0, maxval=1
)
with tf.GradientTape() as tape:
    test_result = model(test_input)

for tv, tvg in zip(model.trainable_variables, tape.gradient(test_result, model.trainable_variables)):
    print(tv.name, tv.shape, tvg is not None)
# Out:
# (None, 28, 28, 6, 3, 4)
# (None, 10, 10, 16, 3, 4)
# (1, 28, 28, 6, 3, 4)
# (1, 10, 10, 16, 3, 4)
# v_input_conv/Variable:0 (26, 1, 6) True
# v_conv_fractal/v_input/Variable:0 (26, 2) True
# v_conv_fractal/v_fractal/Variable:0 (3, 4) True
# v_conv/Variable:0 (151, 1, 16) True
# v_conv_fractal_1/v_input/Variable:0 (151, 2) True
# v_conv_fractal_1/v_fractal/Variable:0 (3, 4) True
# v_conv_1/Variable:0 (401, 1, 10) True

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(3,))

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 534.50096 sec
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_2 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_4 (VConvFract (None, 4, 14, 14, 6)      94
# _________________________________________________________________
# v_conv_4 (VConv)             (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_5 (VConvFract (None, 4, 5, 5, 16)       469
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(4,))

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 565.84298 sec
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_4 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_8 (VConvFract (None, 4, 14, 14, 6)      124
# _________________________________________________________________
# v_conv_8 (VConv)             (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_9 (VConvFract (None, 4, 5, 5, 16)       624
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal5(dataset_shapes, True, hidden_layer_units=(5,))

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 662.10206 sec
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv_5 (VInputConv)  (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal_10 (VConvFrac (None, 4, 14, 14, 6)      154
# _________________________________________________________________
# v_conv_10 (VConv)            (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_11 (VConvFrac (None, 4, 5, 5, 16)       779
# _________________________________________________________________
# ...

# %%
model = get_le_net_5_fractal6(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 611.27365 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# v_input_conv (VInputConv)    (None, 26, 28, 28, 6)     156
# _________________________________________________________________
# v_conv_fractal (VConvFractal (None, 25, 14, 14, 6)     277
# _________________________________________________________________
# v_conv (VConv)               (None, 151, 10, 10, 16)   2416
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 65, 5, 5, 16)      1537
# _________________________________________________________________
# ...

# %% [markdown]
# ### CS(5)

# %%
model = get_scalar_conv_model2(dataset_shapes)

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 24.76620 sec
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 5)         50
# _________________________________________________________________
# re_lu (ReLU)                 (None, 26, 26, 5)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 10)        1260
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 22, 22, 10)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 10)          0
# _________________________________________________________________
# ...

# %% [markdown]
# ### CV(5):U(2)

# %%
model = get_vector_conv_model2(dataset_shapes, False)

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 465.18769 sec
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# v_input_conv (VInputConv)    (None, 10, 26, 26, 5)     50
# _________________________________________________________________
# v_conv_fractal (VConvFractal (None, 126, 22, 22, 10)   3250
# _________________________________________________________________
# v_conv (VConv)               (None, 484, 1, 1, 10)     0
# _________________________________________________________________
# v_output_conv (VOutputConv)  (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# ...
# Total params: 3,300
# Trainable params: 3,300
# Non-trainable params: 0
# ...

# %% [markdown]
# ### CV(5):U(2)

# %%
model = get_vector_conv_model2(dataset_shapes, True)

test_model(model, train_dataset, test_dataset, epochs=5, loss_name="mean_squared_error", measure_name="val_mean_squared_error", \
    print_summary=True)
# Out:
# Elapsed training time: 467.00589 sec
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# v_input_conv_1 (VInputConv)  (None, 10, 26, 26, 5)     50
# _________________________________________________________________
# v_conv_fractal_1 (VConvFract (None, 126, 22, 22, 10)   1658
# _________________________________________________________________
# v_conv_1 (VConv)             (None, 484, 1, 1, 10)     0
# _________________________________________________________________
# v_output_conv_1 (VOutputConv (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# ...
# Total params: 1,708
# Trainable params: 1,708
# Non-trainable params: 0
# ...
